# %%
display(
    spark.sql(
        """
            SELECT
                fp.payment_type,
                COUNT(fp.payment_type) AS transaction_count
            FROM lh_gold.dbo.fact_payment fp
            GROUP BY fp.payment_type
            ORDER BY transaction_count DESC
        """
    )
)
# Out:
# StatementMeta(, 71166fe6-f60f-4595-b6c4-c3b1688ec379, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7a8e529a-c66c-4664-bcaf-e516f51abfc3)
